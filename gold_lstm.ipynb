# %% [markdown]
# <a href="https://colab.research.google.com/github/balaswejan02/distilbert-training-beginner/blob/main/gold_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
